# %%
import gymnasium as gym

# %%
env = gym.make("ALE/MarioBros-v5", render_mode="human")

# %%
observation, info = env.reset()

for _ in range(1000):
    action = env.action_space.sample()  # agent policy that uses the observation and info
    observation, reward, terminated, truncated, info = env.step(action)
    print(observation.shape, reward, terminated, truncated, info)

    if terminated or truncated:
        observation, info = env.reset()

env.close()
# Out:
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 4, 'frame_number': 5865}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 8, 'frame_number': 5869}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 12, 'frame_number': 5873}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 16, 'frame_number': 5877}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 20, 'frame_number': 5881}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 24, 'frame_number': 5885}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 28, 'frame_number': 5889}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 32, 'frame_number': 5893}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 36, 'frame_number': 5897}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 40, 'frame_number': 5901}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 44, 'frame_number': 5905}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 48, 'frame_number': 5909}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 52, 'frame_number': 5913}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 56, 'frame_number': 5917}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 60, 'frame_number': 5921}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 64, 'frame_number': 5925}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 68, 'frame_number': 5929}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 72, 'frame_number': 5933}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 76, 'frame_number': 5937}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 80, 'frame_number': 5941}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 84, 'frame_number': 5945}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 88, 'frame_number': 5949}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 92, 'frame_number': 5953}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 96, 'frame_number': 5957}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 100, 'frame_number': 5961}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 104, 'frame_number': 5965}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 108, 'frame_number': 5969}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 112, 'frame_number': 5973}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 116, 'frame_number': 5977}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 120, 'frame_number': 5981}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 124, 'frame_number': 5985}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 128, 'frame_number': 5989}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 132, 'frame_number': 5993}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 136, 'frame_number': 5997}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 140, 'frame_number': 6001}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 144, 'frame_number': 6005}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 148, 'frame_number': 6009}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 152, 'frame_number': 6013}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 156, 'frame_number': 6017}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 160, 'frame_number': 6021}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 164, 'frame_number': 6025}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 168, 'frame_number': 6029}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 172, 'frame_number': 6033}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 176, 'frame_number': 6037}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 180, 'frame_number': 6041}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 184, 'frame_number': 6045}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 188, 'frame_number': 6049}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 192, 'frame_number': 6053}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 196, 'frame_number': 6057}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 200, 'frame_number': 6061}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 204, 'frame_number': 6065}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 208, 'frame_number': 6069}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 212, 'frame_number': 6073}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 216, 'frame_number': 6077}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 220, 'frame_number': 6081}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 224, 'frame_number': 6085}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 228, 'frame_number': 6089}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 232, 'frame_number': 6093}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 236, 'frame_number': 6097}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 240, 'frame_number': 6101}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 244, 'frame_number': 6105}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 248, 'frame_number': 6109}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 252, 'frame_number': 6113}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 256, 'frame_number': 6117}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 260, 'frame_number': 6121}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 264, 'frame_number': 6125}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 268, 'frame_number': 6129}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 272, 'frame_number': 6133}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 276, 'frame_number': 6137}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 280, 'frame_number': 6141}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 284, 'frame_number': 6145}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 288, 'frame_number': 6149}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 292, 'frame_number': 6153}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 296, 'frame_number': 6157}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 300, 'frame_number': 6161}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 304, 'frame_number': 6165}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 308, 'frame_number': 6169}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 312, 'frame_number': 6173}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 316, 'frame_number': 6177}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 320, 'frame_number': 6181}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 324, 'frame_number': 6185}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 328, 'frame_number': 6189}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 332, 'frame_number': 6193}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 336, 'frame_number': 6197}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 340, 'frame_number': 6201}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 344, 'frame_number': 6205}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 348, 'frame_number': 6209}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 352, 'frame_number': 6213}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 356, 'frame_number': 6217}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 360, 'frame_number': 6221}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 364, 'frame_number': 6225}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 368, 'frame_number': 6229}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 372, 'frame_number': 6233}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 376, 'frame_number': 6237}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 380, 'frame_number': 6241}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 384, 'frame_number': 6245}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 388, 'frame_number': 6249}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 392, 'frame_number': 6253}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 396, 'frame_number': 6257}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 400, 'frame_number': 6261}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 404, 'frame_number': 6265}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 408, 'frame_number': 6269}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 412, 'frame_number': 6273}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 416, 'frame_number': 6277}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 420, 'frame_number': 6281}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 424, 'frame_number': 6285}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 428, 'frame_number': 6289}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 432, 'frame_number': 6293}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 436, 'frame_number': 6297}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 440, 'frame_number': 6301}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 444, 'frame_number': 6305}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 448, 'frame_number': 6309}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 452, 'frame_number': 6313}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 456, 'frame_number': 6317}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 460, 'frame_number': 6321}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 464, 'frame_number': 6325}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 468, 'frame_number': 6329}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 472, 'frame_number': 6333}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 476, 'frame_number': 6337}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 480, 'frame_number': 6341}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 484, 'frame_number': 6345}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 488, 'frame_number': 6349}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 492, 'frame_number': 6353}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 496, 'frame_number': 6357}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 500, 'frame_number': 6361}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 504, 'frame_number': 6365}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 508, 'frame_number': 6369}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 512, 'frame_number': 6373}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 516, 'frame_number': 6377}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 520, 'frame_number': 6381}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 524, 'frame_number': 6385}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 528, 'frame_number': 6389}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 532, 'frame_number': 6393}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 536, 'frame_number': 6397}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 540, 'frame_number': 6401}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 544, 'frame_number': 6405}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 548, 'frame_number': 6409}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 552, 'frame_number': 6413}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 556, 'frame_number': 6417}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 560, 'frame_number': 6421}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 564, 'frame_number': 6425}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 568, 'frame_number': 6429}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 572, 'frame_number': 6433}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 576, 'frame_number': 6437}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 580, 'frame_number': 6441}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 584, 'frame_number': 6445}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 588, 'frame_number': 6449}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 592, 'frame_number': 6453}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 596, 'frame_number': 6457}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 600, 'frame_number': 6461}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 604, 'frame_number': 6465}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 608, 'frame_number': 6469}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 612, 'frame_number': 6473}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 616, 'frame_number': 6477}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 620, 'frame_number': 6481}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 624, 'frame_number': 6485}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 628, 'frame_number': 6489}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 632, 'frame_number': 6493}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 636, 'frame_number': 6497}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 640, 'frame_number': 6501}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 644, 'frame_number': 6505}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 648, 'frame_number': 6509}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 652, 'frame_number': 6513}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 656, 'frame_number': 6517}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 660, 'frame_number': 6521}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 664, 'frame_number': 6525}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 668, 'frame_number': 6529}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 672, 'frame_number': 6533}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 676, 'frame_number': 6537}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 680, 'frame_number': 6541}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 684, 'frame_number': 6545}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 688, 'frame_number': 6549}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 692, 'frame_number': 6553}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 696, 'frame_number': 6557}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 700, 'frame_number': 6561}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 704, 'frame_number': 6565}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 708, 'frame_number': 6569}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 712, 'frame_number': 6573}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 716, 'frame_number': 6577}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 720, 'frame_number': 6581}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 724, 'frame_number': 6585}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 728, 'frame_number': 6589}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 732, 'frame_number': 6593}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 736, 'frame_number': 6597}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 740, 'frame_number': 6601}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 744, 'frame_number': 6605}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 748, 'frame_number': 6609}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 752, 'frame_number': 6613}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 756, 'frame_number': 6617}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 760, 'frame_number': 6621}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 764, 'frame_number': 6625}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 768, 'frame_number': 6629}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 772, 'frame_number': 6633}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 776, 'frame_number': 6637}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 780, 'frame_number': 6641}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 784, 'frame_number': 6645}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 788, 'frame_number': 6649}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 792, 'frame_number': 6653}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 796, 'frame_number': 6657}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 800, 'frame_number': 6661}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 804, 'frame_number': 6665}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 808, 'frame_number': 6669}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 812, 'frame_number': 6673}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 816, 'frame_number': 6677}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 820, 'frame_number': 6681}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 824, 'frame_number': 6685}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 828, 'frame_number': 6689}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 832, 'frame_number': 6693}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 836, 'frame_number': 6697}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 840, 'frame_number': 6701}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 844, 'frame_number': 6705}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 848, 'frame_number': 6709}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 852, 'frame_number': 6713}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 856, 'frame_number': 6717}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 860, 'frame_number': 6721}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 864, 'frame_number': 6725}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 868, 'frame_number': 6729}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 872, 'frame_number': 6733}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 876, 'frame_number': 6737}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 880, 'frame_number': 6741}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 884, 'frame_number': 6745}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 888, 'frame_number': 6749}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 892, 'frame_number': 6753}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 896, 'frame_number': 6757}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 900, 'frame_number': 6761}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 904, 'frame_number': 6765}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 908, 'frame_number': 6769}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 912, 'frame_number': 6773}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 916, 'frame_number': 6777}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 920, 'frame_number': 6781}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 924, 'frame_number': 6785}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 928, 'frame_number': 6789}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 932, 'frame_number': 6793}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 936, 'frame_number': 6797}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 940, 'frame_number': 6801}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 944, 'frame_number': 6805}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 948, 'frame_number': 6809}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 952, 'frame_number': 6813}
# (210, 160, 3) 0.0 False False {'lives': 5, 'episode_frame_number': 956, 'frame_number': 6817}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 960, 'frame_number': 6821}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 964, 'frame_number': 6825}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 968, 'frame_number': 6829}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 972, 'frame_number': 6833}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 976, 'frame_number': 6837}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 980, 'frame_number': 6841}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 984, 'frame_number': 6845}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 988, 'frame_number': 6849}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 992, 'frame_number': 6853}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 996, 'frame_number': 6857}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1000, 'frame_number': 6861}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1004, 'frame_number': 6865}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1008, 'frame_number': 6869}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1012, 'frame_number': 6873}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1016, 'frame_number': 6877}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1020, 'frame_number': 6881}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1024, 'frame_number': 6885}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1028, 'frame_number': 6889}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1032, 'frame_number': 6893}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1036, 'frame_number': 6897}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1040, 'frame_number': 6901}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1044, 'frame_number': 6905}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1048, 'frame_number': 6909}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1052, 'frame_number': 6913}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1056, 'frame_number': 6917}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1060, 'frame_number': 6921}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1064, 'frame_number': 6925}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1068, 'frame_number': 6929}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1072, 'frame_number': 6933}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1076, 'frame_number': 6937}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1080, 'frame_number': 6941}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1084, 'frame_number': 6945}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1088, 'frame_number': 6949}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1092, 'frame_number': 6953}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1096, 'frame_number': 6957}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1100, 'frame_number': 6961}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1104, 'frame_number': 6965}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1108, 'frame_number': 6969}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1112, 'frame_number': 6973}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1116, 'frame_number': 6977}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1120, 'frame_number': 6981}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1124, 'frame_number': 6985}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1128, 'frame_number': 6989}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1132, 'frame_number': 6993}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1136, 'frame_number': 6997}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1140, 'frame_number': 7001}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1144, 'frame_number': 7005}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1148, 'frame_number': 7009}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1152, 'frame_number': 7013}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1156, 'frame_number': 7017}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1160, 'frame_number': 7021}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1164, 'frame_number': 7025}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1168, 'frame_number': 7029}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1172, 'frame_number': 7033}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1176, 'frame_number': 7037}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1180, 'frame_number': 7041}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1184, 'frame_number': 7045}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1188, 'frame_number': 7049}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1192, 'frame_number': 7053}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1196, 'frame_number': 7057}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1200, 'frame_number': 7061}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1204, 'frame_number': 7065}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1208, 'frame_number': 7069}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1212, 'frame_number': 7073}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1216, 'frame_number': 7077}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1220, 'frame_number': 7081}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1224, 'frame_number': 7085}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1228, 'frame_number': 7089}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1232, 'frame_number': 7093}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1236, 'frame_number': 7097}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1240, 'frame_number': 7101}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1244, 'frame_number': 7105}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1248, 'frame_number': 7109}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1252, 'frame_number': 7113}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1256, 'frame_number': 7117}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1260, 'frame_number': 7121}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1264, 'frame_number': 7125}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1268, 'frame_number': 7129}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1272, 'frame_number': 7133}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1276, 'frame_number': 7137}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1280, 'frame_number': 7141}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1284, 'frame_number': 7145}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1288, 'frame_number': 7149}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1292, 'frame_number': 7153}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1296, 'frame_number': 7157}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1300, 'frame_number': 7161}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1304, 'frame_number': 7165}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1308, 'frame_number': 7169}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1312, 'frame_number': 7173}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1316, 'frame_number': 7177}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1320, 'frame_number': 7181}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1324, 'frame_number': 7185}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1328, 'frame_number': 7189}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1332, 'frame_number': 7193}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1336, 'frame_number': 7197}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1340, 'frame_number': 7201}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1344, 'frame_number': 7205}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1348, 'frame_number': 7209}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1352, 'frame_number': 7213}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1356, 'frame_number': 7217}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1360, 'frame_number': 7221}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1364, 'frame_number': 7225}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1368, 'frame_number': 7229}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1372, 'frame_number': 7233}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1376, 'frame_number': 7237}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1380, 'frame_number': 7241}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1384, 'frame_number': 7245}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1388, 'frame_number': 7249}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1392, 'frame_number': 7253}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1396, 'frame_number': 7257}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1400, 'frame_number': 7261}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1404, 'frame_number': 7265}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1408, 'frame_number': 7269}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1412, 'frame_number': 7273}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1416, 'frame_number': 7277}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1420, 'frame_number': 7281}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1424, 'frame_number': 7285}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1428, 'frame_number': 7289}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1432, 'frame_number': 7293}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1436, 'frame_number': 7297}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1440, 'frame_number': 7301}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1444, 'frame_number': 7305}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1448, 'frame_number': 7309}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1452, 'frame_number': 7313}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1456, 'frame_number': 7317}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1460, 'frame_number': 7321}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1464, 'frame_number': 7325}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1468, 'frame_number': 7329}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1472, 'frame_number': 7333}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1476, 'frame_number': 7337}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1480, 'frame_number': 7341}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1484, 'frame_number': 7345}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1488, 'frame_number': 7349}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1492, 'frame_number': 7353}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1496, 'frame_number': 7357}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1500, 'frame_number': 7361}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1504, 'frame_number': 7365}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1508, 'frame_number': 7369}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1512, 'frame_number': 7373}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1516, 'frame_number': 7377}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1520, 'frame_number': 7381}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1524, 'frame_number': 7385}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1528, 'frame_number': 7389}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1532, 'frame_number': 7393}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1536, 'frame_number': 7397}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1540, 'frame_number': 7401}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1544, 'frame_number': 7405}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1548, 'frame_number': 7409}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1552, 'frame_number': 7413}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1556, 'frame_number': 7417}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1560, 'frame_number': 7421}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1564, 'frame_number': 7425}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1568, 'frame_number': 7429}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1572, 'frame_number': 7433}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1576, 'frame_number': 7437}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1580, 'frame_number': 7441}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1584, 'frame_number': 7445}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1588, 'frame_number': 7449}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1592, 'frame_number': 7453}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1596, 'frame_number': 7457}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1600, 'frame_number': 7461}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1604, 'frame_number': 7465}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1608, 'frame_number': 7469}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1612, 'frame_number': 7473}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1616, 'frame_number': 7477}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1620, 'frame_number': 7481}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1624, 'frame_number': 7485}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1628, 'frame_number': 7489}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1632, 'frame_number': 7493}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1636, 'frame_number': 7497}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1640, 'frame_number': 7501}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1644, 'frame_number': 7505}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1648, 'frame_number': 7509}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1652, 'frame_number': 7513}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1656, 'frame_number': 7517}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1660, 'frame_number': 7521}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1664, 'frame_number': 7525}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1668, 'frame_number': 7529}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1672, 'frame_number': 7533}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1676, 'frame_number': 7537}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1680, 'frame_number': 7541}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1684, 'frame_number': 7545}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1688, 'frame_number': 7549}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1692, 'frame_number': 7553}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1696, 'frame_number': 7557}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1700, 'frame_number': 7561}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1704, 'frame_number': 7565}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1708, 'frame_number': 7569}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1712, 'frame_number': 7573}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1716, 'frame_number': 7577}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1720, 'frame_number': 7581}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1724, 'frame_number': 7585}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1728, 'frame_number': 7589}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1732, 'frame_number': 7593}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1736, 'frame_number': 7597}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1740, 'frame_number': 7601}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1744, 'frame_number': 7605}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1748, 'frame_number': 7609}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1752, 'frame_number': 7613}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1756, 'frame_number': 7617}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1760, 'frame_number': 7621}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1764, 'frame_number': 7625}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1768, 'frame_number': 7629}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1772, 'frame_number': 7633}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1776, 'frame_number': 7637}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1780, 'frame_number': 7641}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1784, 'frame_number': 7645}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1788, 'frame_number': 7649}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1792, 'frame_number': 7653}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1796, 'frame_number': 7657}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1800, 'frame_number': 7661}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1804, 'frame_number': 7665}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1808, 'frame_number': 7669}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1812, 'frame_number': 7673}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1816, 'frame_number': 7677}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1820, 'frame_number': 7681}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1824, 'frame_number': 7685}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1828, 'frame_number': 7689}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1832, 'frame_number': 7693}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1836, 'frame_number': 7697}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1840, 'frame_number': 7701}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1844, 'frame_number': 7705}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1848, 'frame_number': 7709}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1852, 'frame_number': 7713}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1856, 'frame_number': 7717}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1860, 'frame_number': 7721}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1864, 'frame_number': 7725}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1868, 'frame_number': 7729}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1872, 'frame_number': 7733}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1876, 'frame_number': 7737}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1880, 'frame_number': 7741}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1884, 'frame_number': 7745}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1888, 'frame_number': 7749}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1892, 'frame_number': 7753}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1896, 'frame_number': 7757}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1900, 'frame_number': 7761}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1904, 'frame_number': 7765}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1908, 'frame_number': 7769}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1912, 'frame_number': 7773}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1916, 'frame_number': 7777}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1920, 'frame_number': 7781}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1924, 'frame_number': 7785}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1928, 'frame_number': 7789}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1932, 'frame_number': 7793}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1936, 'frame_number': 7797}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1940, 'frame_number': 7801}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1944, 'frame_number': 7805}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1948, 'frame_number': 7809}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1952, 'frame_number': 7813}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1956, 'frame_number': 7817}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1960, 'frame_number': 7821}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1964, 'frame_number': 7825}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1968, 'frame_number': 7829}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1972, 'frame_number': 7833}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1976, 'frame_number': 7837}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1980, 'frame_number': 7841}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1984, 'frame_number': 7845}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1988, 'frame_number': 7849}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1992, 'frame_number': 7853}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 1996, 'frame_number': 7857}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 2000, 'frame_number': 7861}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 2004, 'frame_number': 7865}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 2008, 'frame_number': 7869}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 2012, 'frame_number': 7873}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 2016, 'frame_number': 7877}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 2020, 'frame_number': 7881}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 2024, 'frame_number': 7885}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 2028, 'frame_number': 7889}
# (210, 160, 3) 0.0 False False {'lives': 2, 'episode_frame_number': 2032, 'frame_number': 7893}
# ...
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 896, 'frame_number': 9192}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 900, 'frame_number': 9196}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 904, 'frame_number': 9200}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 908, 'frame_number': 9204}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 912, 'frame_number': 9208}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 916, 'frame_number': 9212}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 920, 'frame_number': 9216}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 924, 'frame_number': 9220}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 928, 'frame_number': 9224}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 932, 'frame_number': 9228}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 936, 'frame_number': 9232}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 940, 'frame_number': 9236}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 944, 'frame_number': 9240}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 948, 'frame_number': 9244}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 952, 'frame_number': 9248}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 956, 'frame_number': 9252}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 960, 'frame_number': 9256}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 964, 'frame_number': 9260}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 968, 'frame_number': 9264}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 972, 'frame_number': 9268}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 976, 'frame_number': 9272}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 980, 'frame_number': 9276}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 984, 'frame_number': 9280}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 988, 'frame_number': 9284}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 992, 'frame_number': 9288}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 996, 'frame_number': 9292}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1000, 'frame_number': 9296}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1004, 'frame_number': 9300}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1008, 'frame_number': 9304}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1012, 'frame_number': 9308}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1016, 'frame_number': 9312}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1020, 'frame_number': 9316}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1024, 'frame_number': 9320}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1028, 'frame_number': 9324}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1032, 'frame_number': 9328}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1036, 'frame_number': 9332}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1040, 'frame_number': 9336}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1044, 'frame_number': 9340}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1048, 'frame_number': 9344}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1052, 'frame_number': 9348}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1056, 'frame_number': 9352}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1060, 'frame_number': 9356}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1064, 'frame_number': 9360}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1068, 'frame_number': 9364}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1072, 'frame_number': 9368}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1076, 'frame_number': 9372}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1080, 'frame_number': 9376}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1084, 'frame_number': 9380}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1088, 'frame_number': 9384}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1092, 'frame_number': 9388}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1096, 'frame_number': 9392}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1100, 'frame_number': 9396}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1104, 'frame_number': 9400}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1108, 'frame_number': 9404}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1112, 'frame_number': 9408}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1116, 'frame_number': 9412}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1120, 'frame_number': 9416}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1124, 'frame_number': 9420}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1128, 'frame_number': 9424}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1132, 'frame_number': 9428}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1136, 'frame_number': 9432}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1140, 'frame_number': 9436}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1144, 'frame_number': 9440}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1148, 'frame_number': 9444}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1152, 'frame_number': 9448}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1156, 'frame_number': 9452}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1160, 'frame_number': 9456}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1164, 'frame_number': 9460}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1168, 'frame_number': 9464}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1172, 'frame_number': 9468}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1176, 'frame_number': 9472}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1180, 'frame_number': 9476}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1184, 'frame_number': 9480}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1188, 'frame_number': 9484}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1192, 'frame_number': 9488}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1196, 'frame_number': 9492}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1200, 'frame_number': 9496}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1204, 'frame_number': 9500}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1208, 'frame_number': 9504}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1212, 'frame_number': 9508}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1216, 'frame_number': 9512}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1220, 'frame_number': 9516}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1224, 'frame_number': 9520}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1228, 'frame_number': 9524}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1232, 'frame_number': 9528}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1236, 'frame_number': 9532}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1240, 'frame_number': 9536}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1244, 'frame_number': 9540}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1248, 'frame_number': 9544}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1252, 'frame_number': 9548}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1256, 'frame_number': 9552}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1260, 'frame_number': 9556}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1264, 'frame_number': 9560}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1268, 'frame_number': 9564}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1272, 'frame_number': 9568}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1276, 'frame_number': 9572}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1280, 'frame_number': 9576}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1284, 'frame_number': 9580}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1288, 'frame_number': 9584}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1292, 'frame_number': 9588}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1296, 'frame_number': 9592}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1300, 'frame_number': 9596}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1304, 'frame_number': 9600}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1308, 'frame_number': 9604}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1312, 'frame_number': 9608}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1316, 'frame_number': 9612}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1320, 'frame_number': 9616}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1324, 'frame_number': 9620}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1328, 'frame_number': 9624}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1332, 'frame_number': 9628}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1336, 'frame_number': 9632}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1340, 'frame_number': 9636}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1344, 'frame_number': 9640}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1348, 'frame_number': 9644}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1352, 'frame_number': 9648}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1356, 'frame_number': 9652}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1360, 'frame_number': 9656}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1364, 'frame_number': 9660}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1368, 'frame_number': 9664}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1372, 'frame_number': 9668}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1376, 'frame_number': 9672}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1380, 'frame_number': 9676}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1384, 'frame_number': 9680}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1388, 'frame_number': 9684}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1392, 'frame_number': 9688}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1396, 'frame_number': 9692}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1400, 'frame_number': 9696}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1404, 'frame_number': 9700}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1408, 'frame_number': 9704}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1412, 'frame_number': 9708}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1416, 'frame_number': 9712}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1420, 'frame_number': 9716}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1424, 'frame_number': 9720}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1428, 'frame_number': 9724}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1432, 'frame_number': 9728}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1436, 'frame_number': 9732}
# (210, 160, 3) 0.0 False False {'lives': 4, 'episode_frame_number': 1440, 'frame_number': 9736}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1444, 'frame_number': 9740}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1448, 'frame_number': 9744}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1452, 'frame_number': 9748}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1456, 'frame_number': 9752}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1460, 'frame_number': 9756}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1464, 'frame_number': 9760}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1468, 'frame_number': 9764}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1472, 'frame_number': 9768}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1476, 'frame_number': 9772}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1480, 'frame_number': 9776}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1484, 'frame_number': 9780}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1488, 'frame_number': 9784}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1492, 'frame_number': 9788}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1496, 'frame_number': 9792}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1500, 'frame_number': 9796}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1504, 'frame_number': 9800}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1508, 'frame_number': 9804}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1512, 'frame_number': 9808}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1516, 'frame_number': 9812}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1520, 'frame_number': 9816}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1524, 'frame_number': 9820}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1528, 'frame_number': 9824}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1532, 'frame_number': 9828}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1536, 'frame_number': 9832}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1540, 'frame_number': 9836}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1544, 'frame_number': 9840}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1548, 'frame_number': 9844}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1552, 'frame_number': 9848}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1556, 'frame_number': 9852}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1560, 'frame_number': 9856}
# (210, 160, 3) 0.0 False False {'lives': 3, 'episode_frame_number': 1564, 'frame_number': 9860}

# %% [markdown]
# # Manual:
# [Atari Mario bros manual](https://atariage.com/manual_html_page.php?SoftwareLabelID=286)
